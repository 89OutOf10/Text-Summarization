# %% [markdown]
# #https://www.topbots.com/guide-to-human-like-text-summarization/

# %%
# !pip install torch
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.1 MB 8.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 62.2 MB/s
# ...
#      |████████████████████████████████| 59 kB 9.4 MB/s
# ...
#      |████████████████████████████████| 895 kB 63.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 51.0 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model = AutoModelForSeq2SeqLM.from_pretrained('t5-base')
tokenizer = AutoTokenizer.from_pretrained('t5-base')
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]

# %%
text = """Since we have n number of the point where, for example, this is a 6 we need this kind of operation 18 times. 

Okay, and for second step you change the cluster Center to the average of its assigned point. 

So going into the center of these two points will be the Optimized will write and actually this can be obtained by taking the derivative and set it to 0. 

But from the Ace point of view, she has some distance, so a things they are not equal to together. 

So every single points if you apply the triangle inequality, you always find that these distance are the minimum. 

The objective is shown like, is we find mu the mean of Cluster and see is the assignment.  

We have to measure this distance, with this one, with this one, with this one, with this one, with this one, with this one. 

If we have these two black data points are here, assigned into this green class will take a course in times of operation right in this 1000 degrees. 

And so, in this case, the number of operation is to but Egypt always guarantee that you will get only two points in this cluster. 

In k-means Loop and first we can think about rolling time for iteration or iteration we have with these two steps. 

So, content show director, and I found that I missed the first slide talks about properties of k-means clustering. 

And finally, I forgot to mention this one in the, where's this one guarantee is to decrease this objective function. 

So you have a here you will be here the distance of a and b is like this and then we also have see this is the the sea and all this a see this. 

As you saw in the previous example, k-means clustering is guaranteed to converge.

"""

# %%
tokens_input = tokenizer.encode('summerize:'+text,
                                return_tensors='pt',
                                max_length=tokenizer.model_max_length,
                                truncation=True)

# %%
summary_ids = model.generate(tokens_input, min_length=80,
                             max_length=150, length_penalty=15,
                             num_beams=4)

summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# %%
print(summary)
# Out:
# a n. summerize:Since we have n number of the point where, for example, this is a 6 we need this kind of operation 18 times. k-means k-means Loop. k-means Loop. 18 times. this this.. this the. this. a. the, the the. k-means.. k-...
