# %%
# !pip install -q bert-extractive-summarizer
# !pip install -q spacy==2.1.3
# !pip install -q transformers==4.5.1
# !pip install -q neuralcoref
# !pip install -q torch==1.4.0.
# Out:
#      |████████████████████████████████| 3.1 MB 39.6 MB/s
#      |████████████████████████████████| 596 kB 61.8 MB/s
#      |████████████████████████████████| 3.3 MB 72.9 MB/s
#      |████████████████████████████████| 61 kB 556 kB/s
#      |████████████████████████████████| 895 kB 47.6 MB/s
#      |████████████████████████████████| 27.7 MB 1.5 MB/s
#      |████████████████████████████████| 3.2 MB 59.8 MB/s
#      |████████████████████████████████| 2.1 MB 43.4 MB/s
#      |████████████████████████████████| 82 kB 403 kB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 2.2.5 requires spacy>=2.2.2, but you have spacy 2.1.3 which is incompatible.
#      |████████████████████████████████| 2.1 MB 35.7 MB/s
#      |████████████████████████████████| 286 kB 39.2 MB/s
#      |████████████████████████████████| 131 kB 72.6 MB/s
#      |████████████████████████████████| 79 kB 8.2 MB/s
#      |████████████████████████████████| 8.4 MB 41.7 MB/s
#      |████████████████████████████████| 127 kB 61.0 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
#      |████████████████████████████████| 753.4 MB 6.6 kB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.11.1+cu111 requires torch==1.10.0, but you have torch 1.4.0 which is incompatible.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.4.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.4.0 which is incompatible.

# %%
from summarizer import Summarizer
from pprint import pprint

# %%
with open("MIT lecture.txt", 'r') as file:
    data = file.read().replace('\n', '')

# %%
data = data.replace("\ufeff", "")

# %%
data[0:100]
# Out:
# 'Good afternoon, everyone, and welcome to MIT 6s 191. Introduction to deep learning. My name is Alexa'

# %%
model = Summarizer()
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
result = model(data, num_sentences=10, min_length=60)

# %%
full = ''.join(result)

# %%
pprint(full)
# Out:
# ('191 is a two-week boot camp on everything deep learning and will cover a ton '
#  'of material in only two weeks. Deep learning part here that a mighty leap '
#  'one is revolutionising. So incredibly fast that even within the past year, '
#  'the state of the art has significantly Advanced and the video you saw that '
#  'we used last year use deep learning, but it was not a particularly easy '
#  'video to create it. Now doing so will make you eligible to win some of the '
#  'prizes that you can see on the right hand side. Now, again, three minutes is '
#  'extremely short to actually present your ideas and present your project. The '
#  'second option to fulfill your grade requirement is to write a one-page '
#  'review on a deep learning paper here. If you would just like to use one of '
#  'those for your view, in addition to the final project price. Now, the point '
#  'of an activation function, And is to actually introduce nonlinearities into '
#  'our Network. We can illustrate this space actually, but this feature When '
#  "we're dealing with a small dimensional data, like in this case, we only have "
#  'two Dimensions but soon will start to talk about problems where we have '
#  'thousands or millions or in some cases even billions of input of Weights in '
#  'our neural network, and then drawing these types of plots becomes extremely '
#  'challenging and not really possible anymore. Just like we saw it and learn '
#  'about already that forward propagation of information is simply the dot '
#  'product or the matrix. And then we applied this non-linearity to compute the '
#  'output. We can stack each of these dense layers on top of each other, each '
#  "one. But with the last output layer fix to two outputs, if that's how many "
#  'outputs we have. And we can see that the probability that we pass is 0.1 or '
#  "10%, That's not great. Now, I think that we need to start asking ourselves "
#  'is, how can we take that loss function? That essentially means that we want '
#  "to find the W's in our neural network that minimize J of w. J of w is our "
#  'empirical cost function that we saw in the previous slides, that average '
#  'loss over each data point. Okay, and this will move us a little bit closer '
#  'to the lowest point and we just keep repeating this. We compute the '
#  'gradient, and we take a small step of our weights in the direction of that. '
#  'But now the loss with respect to W1, we can do the same stories before we '
#  'can apply the chain Rule. But really all this boils down to just recursively '
#  'applying this chain rule. These networks in practice that make this process, '
#  'much more complicated in practice. And during your Labs, we encourage each '
#  'of you to really try out each of these different types of optimized. This is '
#  "really taking everything that we've learned in the class and the lecture so "
#  'far. Now that we can focus on this very powerful idea of batching your data '
#  'into mini batches. So this is a summation over every single data point in '
#  'the entire dataset.')
